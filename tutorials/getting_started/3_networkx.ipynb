# %% [markdown]
# # Introduction to FBL: Part 3: NetworkX
#
# For using both FFBO and FBL efficiently and correctly, you should learn
# to use NetworkX, a graph library for Python.
# You can access the documentation here:
# https://networkx.github.io/documentation/stable/
#
#
#
# Let us start with a basic query and get the connectivity dendrogram:

# %%
# %matplotlib inline
my_client = fbl.get_client()
my_client.executeNLPquery('show GABAergic neurons in the ellipsoid body')
my_client.getConnectivityDendrogram()
# Out:
# [FFBOLab Client NLP 2020-08-05 00:30:11] NLP successfully parsed query.
# [FFBOLab Client NLP 2020-08-05 00:30:11] Received a message.
# [FFBOLab Client NLP 2020-08-05 00:30:11] Received a command.
# [FFBOLab Client NLP 2020-08-05 00:30:11] Received data.
# [FFBOLab Client NLP 2020-08-05 00:30:11] Received data.
# [FFBOLab Client NLP 2020-08-05 00:30:11] Received a message.
# [FFBOLab Client NLP 2020-08-05 00:30:11] Received data.
# ['EB']
# [FFBOLab Client NLP 2020-08-05 00:30:12] Received a message.
# [FFBOLab Client NLP 2020-08-05 00:30:12] Received data.

# %% [markdown]
# We can now access the circuit graph as follows:

# %%
circuit_graph = my_client.C.G

# %% [markdown]
# We can for example look at a list of nodes:

# %%
print(circuit_graph.nodes(data=True))
# Out:
# [('{"name": "None-1", "exp": ""}', {'name': 'Gad1-F-200361', 'n': 0.0, 'm': 0.0, 'h': 1.0, 'type': 'neuron', 'class': 'HodgkinHuxley', 'species': 'None', 'hemisphere': 'None', 'neuropil': 'None', 'circuit': 'None', 'from': 'None', 'to': 'None', 'neurotransmitter': 'None', 'experiment_id': 'None', 'rid': 'None'}), ('{"name": "None-2", "exp": ""}', {'name': 'Gad1-F-700098', 'n': 0.0, 'm': 0.0, 'h': 1.0, 'type': 'neuron', 'class': 'HodgkinHuxley', 'species': 'None', 'hemisphere': 'None', 'neuropil': 'None', 'circuit': 'None', 'from': 'None', 'to': 'None', 'neurotransmitter': 'None', 'experiment_id': 'None', 'rid': 'None'}), ('{"name": "None-3", "exp": ""}', {'name': 'Gad1-F-500106', 'n': 0.0, 'm': 0.0, 'h': 1.0, 'type': 'neuron', 'class': 'HodgkinHuxley', 'species': 'None', 'hemisphere': 'None', 'neuropil': 'None', 'circuit': 'None', 'from': 'None', 'to': 'None', 'neurotransmitter': 'None', 'experiment_id': 'None', 'rid': 'None'}), ('{"name": "None-4", "exp": ""}', {'name': 'Gad1-F-100385', 'n': 0.0, 'm': 0.0, 'h': 1.0, 'type': 'neuron', 'class': 'HodgkinHuxley', 'species': 'None', 'hemisphere': 'None', 'neuropil': 'None', 'circuit': 'None', 'from': 'None', 'to': 'None', 'neurotransmitter': 'None', 'experiment_id': 'None', 'rid': 'None'}), ('{"name": "None-5", "exp": ""}', {'name': 'Gad1-F-400135', 'n': 0.0, 'm': 0.0, 'h': 1.0, 'type': 'neuron', 'class': 'HodgkinHuxley', 'species': 'None', 'hemisphere': 'None', 'neuropil': 'None', 'circuit': 'None', 'from': 'None', 'to': 'None', 'neurotransmitter': 'None', 'experiment_id': 'None', 'rid': 'None'}), ('{"name": "None-6", "exp": ""}', {'name': 'Gad1-F-000050', 'n': 0.0, 'm': 0.0, 'h': 1.0, 'type': 'neuron', 'class': 'HodgkinHuxley', 'species': 'None', 'hemisphere': 'None', 'neuropil': 'None', 'circuit': 'None', 'from': 'None', 'to': 'None', 'neurotransmitter': 'None', 'experiment_id': 'None', 'rid': 'None'}), ('{"name": "None-7", "exp": ""}', {'name': 'Gad1-F-200210', 'n': 0.0, 'm': 0.0, 'h': 1.0, 'type': 'neuron', 'class': 'HodgkinHuxley', 'species': 'None', 'hemisphere': 'None', 'neuropil': 'None', 'circuit': 'None', 'from': 'None', 'to': 'None', 'neurotransmitter': 'None', 'experiment_id': 'None', 'rid': 'None'}), ('{"name": "None-8", "exp": ""}', {'name': 'Gad1-F-500380', 'n': 0.0, 'm': 0.0, 'h': 1.0, 'type': 'neuron', 'class': 'HodgkinHuxley', 'species': 'None', 'hemisphere': 'None', 'neuropil': 'None', 'circuit': 'None', 'from': 'None', 'to': 'None', 'neurotransmitter': 'None', 'experiment_id': 'None', 'rid': 'None'}), ('{"name": "None-9", "exp": ""}', {'name': 'Gad1-F-100231', 'n': 0.0, 'm': 0.0, 'h': 1.0, 'type': 'neuron', 'class': 'HodgkinHuxley', 'species': 'None', 'hemisphere': 'None', 'neuropil': 'None', 'circuit': 'None', 'from': 'None', 'to': 'None', 'neurotransmitter': 'None', 'experiment_id': 'None', 'rid': 'None'}), ('{"name": "None-10", "exp": ""}', {'name': 'Gad1-F-300341', 'n': 0.0, 'm': 0.0, 'h': 1.0, 'type': 'neuron', 'class': 'HodgkinHuxley', 'species': 'None', 'hemisphere': 'None', 'neuropil': 'None', 'circuit': 'None', 'from': 'None', 'to': 'None', 'neurotransmitter': 'None', 'experiment_id': 'None', 'rid': 'None'}), ('{"name": "None-11", "exp": ""}', {'name': 'Gad1-F-600135', 'n': 0.0, 'm': 0.0, 'h': 1.0, 'type': 'neuron', 'class': 'HodgkinHuxley', 'species': 'None', 'hemisphere': 'None', 'neuropil': 'None', 'circuit': 'None', 'from': 'None', 'to': 'None', 'neurotransmitter': 'None', 'experiment_id': 'None', 'rid': 'None'}), ('{"name": "None-12", "exp": ""}', {'name': 'Gad1-F-400190', 'n': 0.0, 'm': 0.0, 'h': 1.0, 'type': 'neuron', 'class': 'HodgkinHuxley', 'species': 'None', 'hemisphere': 'None', 'neuropil': 'None', 'circuit': 'None', 'from': 'None', 'to': 'None', 'neurotransmitter': 'None', 'experiment_id': 'None', 'rid': 'None'}), ('{"name": "None-13", "exp": ""}', {'name': 'Gad1-F-000273', 'n': 0.0, 'm': 0.0, 'h': 1.0, 'type': 'neuron', 'class': 'HodgkinHuxley', 'species': 'None', 'hemisphere': 'None', 'neuropil': 'None', 'circuit': 'None', 'from': 'None ...

# %% [markdown]
# Or the edges:

# %%
print(circuit_graph.edges(data=True))
# Out:
# [('{"name": "None-1", "exp": ""}', '{"name": "None-79", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-80", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-81", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-82", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-83", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-84", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-85", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-86", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-87", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-88", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-89", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-90", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-91", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-92", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-93", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-94", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-95", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-96", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-97", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-98", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-99", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-100", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-101", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-102", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-103", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-104", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-105", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-106", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-107", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-108", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-109", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-110", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-111", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-112", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-113", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-114", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-115", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-116", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-117", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-118", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-119", "exp": ""}', {'delay': 0.0, 'tag': 0}), ('{"name": "None-1", "exp": ""}', '{"name": "None-120", "exp": ""}', {'delay': 0.0,  ...

# %% [markdown]
# This circuit is automatically generated in a Neurokernel-executable format using Neuroballad.
#
# For simulations, it is recommended that you start to look at Neurodriver at:
# https://github.com/neurokernel/neurodriver
